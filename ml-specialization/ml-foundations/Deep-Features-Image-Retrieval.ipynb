# %%
import graphlab

# %%
graphlab.canvas.set_target('ipynb')

# %%
image_train = graphlab.SFrame('image_train_data/')
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to vggeorgiev@mail.bg and will expire on July 04, 2018.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: C:\Users\VGEORG~1\AppData\Local\Temp\graphlab_server_1509189597.log.0

# %%
image_train.head()
# Out:
# Columns:
# 	id	int
# 	image	Image
# 	label	str
# 	deep_features	array
# 	image_array	array
#
# Rows: 10
#
# Data:
# +-----+----------------------+------------+-------------------------------+
# |  id |        image         |   label    |         deep_features         |
# +-----+----------------------+------------+-------------------------------+
# |  24 | Height: 32 Width: 32 |    bird    | [0.242871761322, 1.0954537... |
# |  33 | Height: 32 Width: 32 |    cat     | [0.525087952614, 0.0, 0.0,... |
# |  36 | Height: 32 Width: 32 |    cat     | [0.566015958786, 0.0, 0.0,... |
# |  70 | Height: 32 Width: 32 |    dog     | [1.12979578972, 0.0, 0.0, ... |
# |  90 | Height: 32 Width: 32 |    bird    | [1.71786928177, 0.0, 0.0, ... |
# |  97 | Height: 32 Width: 32 | automobile | [1.57818555832, 0.0, 0.0, ... |
# | 107 | Height: 32 Width: 32 |    dog     | [0.0, 0.0, 0.220677852631,... |
# | 121 | Height: 32 Width: 32 |    bird    | [0.0, 0.23753464222, 0.0, ... |
# ...

# %%
image_train['label'].sketch_summary()
# Out:
# +------------------+-------+----------+
# |       item       | value | is exact |
# +------------------+-------+----------+
# |      Length      |  2005 |   Yes    |
# | # Missing Values |   0   |   Yes    |
# | # unique values  |   4   |    No    |
# +------------------+-------+----------+
#
# Most frequent items:
# +-------+------------+-----+-----+------+
# | value | automobile | cat | dog | bird |
# +-------+------------+-----+-----+------+
# | count |    509     | 509 | 509 | 478  |
# +-------+------------+-----+-----+------+

# %%
knn_model = graphlab.nearest_neighbors.create(image_train,features=['deep_features'],
                                             label='id')
# Out:
# Starting brute force nearest neighbors model training.

# %%
def get_images_from_ids(query_result):
    return image_train.filter_by(query_result['reference_label'],'id')

# %%
show_neighbors = lambda i: get_images_from_ids(knn_model.query(image_train[i:i+1]))['image'].show()

# %%
show_neighbors(0)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.0498753   | 12.037ms     |
# | Done         |         | 100         | 201.92ms     |
# +--------------+---------+-------------+--------------+

# %%
automobiles = image_train[image_train['label'] == 'automobile']

# %%
cats = image_train[image_train['label'] == 'cat']

# %%
dogs = image_train[image_train['label'] == 'dog']

# %%
birds = image_train[image_train['label'] == 'bird']

# %%
automobiles_model = graphlab.nearest_neighbors.create(automobiles,features=['deep_features'],
                                             label='id')
# Out:
# Starting brute force nearest neighbors model training.

# %%
cats_model = graphlab.nearest_neighbors.create(cats,features=['deep_features'],
                                             label='id')
# Out:
# Starting brute force nearest neighbors model training.

# %%
dogs_model = graphlab.nearest_neighbors.create(dogs,features=['deep_features'],
                                             label='id')
# Out:
# Starting brute force nearest neighbors model training.

# %%
birds_model = graphlab.nearest_neighbors.create(birds,features=['deep_features'],
                                             label='id')
# Out:
# Starting brute force nearest neighbors model training.

# %%
image_test = graphlab.SFrame('image_test_data/')

# %%
get_images_from_ids(cats_model.query(image_test[0:1]))['image'].show()
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.196464    | 9.024ms      |
# | Done         |         | 100         | 48.128ms     |
# +--------------+---------+-------------+--------------+

# %%
get_images_from_ids(dogs_model.query(image_test[0:1]))['image'].show()
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.196464    | 11.026ms     |
# | Done         |         | 100         | 55.144ms     |
# +--------------+---------+-------------+--------------+

# %%
cats_model.query(image_test[0:1])
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.196464    | 13.036ms     |
# | Done         |         | 100         | 111.304ms    |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	int
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+---------------+------+
# | query_label | reference_label |    distance   | rank |
# +-------------+-----------------+---------------+------+
# |      0      |      16289      |  34.623719208 |  1   |
# |      0      |      45646      | 36.0068799284 |  2   |
# |      0      |      32139      | 36.5200813436 |  3   |
# |      0      |      25713      | 36.7548502521 |  4   |
# |      0      |       331       | 36.8731228168 |  5   |
# ...

# %%
dogs_model.query(image_test[0:1])
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.196464    | 7.02ms       |
# | Done         |         | 100         | 66.182ms     |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	int
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+---------------+------+
# | query_label | reference_label |    distance   | rank |
# +-------------+-----------------+---------------+------+
# |      0      |      16976      | 37.4642628784 |  1   |
# |      0      |      13387      | 37.5666832169 |  2   |
# |      0      |      35867      | 37.6047267079 |  3   |
# |      0      |      44603      | 37.7065585153 |  4   |
# |      0      |       6094      | 38.5113254907 |  5   |
# ...

# %%
image_test[0:1]['image'].show()

# %%
automobiles_test_data = image_test[image_test['label'] == 'automobile']

# %%
cats_test_data = image_test[image_test['label'] == 'cat']

# %%
dogs_test_data = image_test[image_test['label'] == 'dog']

# %%
birds_test_data = image_test[image_test['label'] == 'bird']
